# %% [markdown]
# #1. Installs and Imports

# %%
# # Install NumPy for numerical operations on arrays
# !pip install numpy

# # Install Gym for creating and managing reinforcement learning environments
# !pip install gym

# # Install Optuna for hyperparameter optimization
# !pip install optuna

# # Install Matplotlib for plotting data and creating visualizations
# !pip install matplotlib
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 7.5 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 17.9 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.6 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0

# %%
# Standard libraries
import random  # For generating random numbers and sampling from distributions

# External libraries (third-party)
import time  # For tracking the exqcution of a program
import numpy as np  # For numerical operations on arrays
import gym  # For creating and managing reinforcement learning environments
from gym import spaces  # For defining custom action and observation spaces in Gym
from gym.utils import seeding  # For seeding random number generators in Gym
import optuna  # For optimizing hyperparameters

# Visualization libraries
import matplotlib.pyplot as plt  # For plotting data
import matplotlib.patches as patches  # For creating custom shapes on plots

# Set a seed
random_seed = 25
# Ensure random sampling occurs according to the seed to ensure results are replicable
rng = random.Random()
rng.seed(random_seed)

# %% [markdown]
# #2. Maze

# %% [markdown]
# ## 2.1. Maze Elements

# %%
AGENT = "A"  # the agent's current position
WALL = "1"  # wall (unpassable)
PATH = "0"  # open path (passable)
START = "S"  # starting position of the agent
SUB_GOAL = "G"  # sub-goal
END = "E"  # end goal
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## 2.2. Maze Layout

# %%
# Define the maze layout
maze = np.array([
    [WALL, WALL, WALL, WALL, WALL, WALL, WALL, WALL, WALL, WALL],
    [WALL, PATH, WALL, PATH, PATH, PATH, WALL, PATH, PATH, WALL],
    [WALL, PATH, WALL, PATH, WALL, PATH, WALL, PATH, WALL, WALL],
    [WALL, PATH, PATH, PATH, WALL, PATH, PATH, PATH, PATH, WALL],
    [WALL, WALL, WALL, PATH, WALL, WALL, WALL, WALL, PATH, WALL],
    [WALL, PATH, WALL, PATH, PATH, PATH, PATH, WALL, PATH, WALL],
    [WALL, PATH, PATH, PATH, WALL, WALL, PATH, PATH, PATH, WALL],
    [WALL, WALL, WALL, PATH, WALL, PATH, WALL, WALL, PATH, WALL],
    [WALL, PATH, PATH, PATH, PATH, PATH, WALL, PATH, PATH, WALL],
    [WALL, WALL, WALL, WALL, WALL, WALL, WALL, WALL, WALL, WALL]
], dtype=object)

# Set the positions
start_pos = (1, 1)  # S
end_pos = (7, 8)  # E
sub_goal_pos = (5, 3)  # G

# Place the start, end, and sub-goal  in the maze
maze[start_pos] = START
maze[end_pos] = END
maze[sub_goal_pos] = SUB_GOAL

# %% [markdown]
# ##2.3. Maze Environment with Sub-goal

# %%
class MazeEnv(gym.Env):
    def __init__(self):
        """
        Initializes the Maze environment. Sets up the action space (4 directions), observation space
        (200 states: 10x10 grid + sub-goal state), and initializes the maze, agent position, and other variables.
        """
        super(MazeEnv, self).__init__()
        # Define the action space (up, down, left, right) and the observation space
        self.action_space = spaces.Discrete(4)  # All possible directions (up, down, left, right)
        self.observation_space = spaces.Discrete(200)  # 10x10 grid and sub-goal state -> 200 states
        # Copy the maze layout and set the starting position
        self.maze = np.copy(maze)
        self.position = start_pos
        self.goal_reached = False
        self.sub_goal_visited = False  # Track if the sub-goal has been visited
        self.seed(random_seed)
        # Define the colormap for rendering the maze
        self.colormap = {
            WALL: 'black',
            PATH: 'white',
            SUB_GOAL: 'deepskyblue',
            END: 'limegreen',
            AGENT: 'red',
            START: 'gold'}

    def step(self, action):
        """
        Executes an action in the environment. Moves the agent according to the action,
        calculates rewards and checks if the agent has reached the sub-goal or the end-goal.
        Returns the new state, reward, done (True if the end-goal is reached), and additional info.
        """
        # Map action numbers to movement directions
        movements = {
            0: (-1, 0), # up
            1: (1, 0),  # down
            2: (0, -1), # left
            3: (0, 1)   # right
            }
        # Get the current position of the agent
        x, y = self.position
        dx, dy = movements[action]
        new_x, new_y = x + dx, y + dy

        # Prevent movement out of bounds (agent stays in place if the move is outside the grid)
        if new_x < 0 or new_x >= self.maze.shape[0] or new_y < 0 or new_y >= self.maze.shape[1]:
            new_x, new_y = x, y  # Stay in the same place if out of bounds

        # Check if the next position is a wall, and if so, the agent stays in the same place
        if self.maze[new_x, new_y] == WALL:
            new_x, new_y = x, y
            reward = -1  # Negative reward for hitting a wall
        else:
            reward = -0.1  # Small penalty for moving

        # Update the agent's position
        self.position = (new_x, new_y)

        # Check if the agent reached the subgoal, and give a small reward if true
        if self.position == sub_goal_pos and not self.sub_goal_visited:
            reward = 1
            self.sub_goal_visited = True  # Update state to reflect sub-goal visit

        # Check if the agent reached the goal
        if self.position == end_pos:
            if self.sub_goal_visited:
                reward = 10  # Only give large reward if sub-goal was visited
                self.goal_reached = True
            else:
                reward = -10  # Penalize reaching the end goal without visiting the sub-goal

        # Determine if the episode is done (i.e., the agent reached the goal)
        done = self.goal_reached
        # Encode the state as a single number (row * grid_width + column)
        new_state = (new_x * 10 + new_y) + (100 if self.sub_goal_visited else 0)  # State encoding
        return new_state, reward, done, {}

    def seed(self, seed=None):
        """
        Set the seed for the environment's random number generators.
        """
        self.np_random, seed = seeding.np_random(seed)
        self.action_space.seed(seed)

    def reset(self):
        """
        Resets the environment to its initial state. The agent is placed at the start position,
        and sub-goal/goal statuses are reset.
        Returns the starting state.
        """
         # Reset the position to the starting position and reset the sub-goal and goal flags
        self.position = start_pos
        self.goal_reached = False
        self.sub_goal_visited = False
        self.seed(random_seed)
        # Return the encoded starting state
        return self.position[0] * 10 + self.position[1]

    def render(self, mode='human'):
        """
        Render the maze in a textual form.
        """
        # Copy the current state of the maze
        temp_maze = np.copy(self.maze)
        # Get the current position of the agent
        x, y = self.position
        temp_maze[x][y] = AGENT if not self.goal_reached else END # Place agent in the maze, or mark the goal if reached
        for row in temp_maze:
            print(' '.join(row)) # Print each row of the maze
        print()

    def colorful_render(self, mode='human', ax=None):
        """
        Renders the maze using a graphical representation with colors for different maze elements (walls, paths, goals).
        Plots the agent as a red circle on the maze.
        """
        # Copy the maze layout
        temp_maze = np.copy(self.maze)

        # Loop over each cell in the maze
        for i in range(temp_maze.shape[0]):
            for j in range(temp_maze.shape[1]):
                # Choose the appropriate color based on the maze element
                if temp_maze[i, j] == PATH:
                    color = self.colormap[PATH]
                elif temp_maze[i, j] == SUB_GOAL:
                    color = self.colormap[SUB_GOAL]
                elif temp_maze[i, j] == START:
                    color = self.colormap[START]
                elif temp_maze[i, j] == END:
                    color = self.colormap[END]
                else:
                    color = self.colormap[WALL]

                # Draw a colored square for each cell
                ax.add_patch(patches.Rectangle((j, temp_maze.shape[0] - i - 1), 1, 1, facecolor=color))  # Invert y-axis and plot each cell as a square

        # Plot the agent as a red circle on the grid
        x, y = self.position
        agent = patches.Circle((y + 0.5, temp_maze.shape[0] - x - 0.5), 0.3, color=self.colormap[AGENT])
        ax.add_patch(agent)

        # Set axes limits
        ax.set_xlim(0, temp_maze.shape[1])
        ax.set_ylim(0, temp_maze.shape[0])
        ax.set_aspect('equal')
        ax.set_xticks([])  # Remove x-axis ticks
        ax.set_yticks([])  # Remove y-axis ticks

    def visualize_policy(self, q_table):
        """
        Visualizes the learned policy on the maze using arrows to represent actions at each state.
        Black arrows indicate actions before the sub-goal is visited, and red arrows indicate actions
        after the sub-goal has been visited.
        """
        # Set up the plot for rendering
        _, ax = plt.subplots()
        temp_maze = np.copy(self.maze)

        # Loop over each cell
        for i in range(temp_maze.shape[0]):
            for j in range(temp_maze.shape[1]):
                # Choose the color based on the maze element
                if temp_maze[i, j] == PATH:
                    color = self.colormap[PATH]
                elif temp_maze[i, j] == SUB_GOAL:
                    color = self.colormap[SUB_GOAL]
                elif temp_maze[i, j] == START:
                    color = self.colormap[START]
                elif temp_maze[i, j] == END:
                    color = self.colormap[END]
                else:
                    color = self.colormap[WALL]

                # Draw each cell as a colored rectangle
                ax.add_patch(patches.Rectangle((j, temp_maze.shape[0] - i - 1), 1, 1, facecolor=color))  # Invert y-axis and plot each cell as a square

        # Add black arrows to represent the learned policy for states before subgoal is visited
        for i in range(temp_maze.shape[0]):
            for j in range(temp_maze.shape[1]):
                state = i * temp_maze.shape[1] + j # Compute the state index
                if temp_maze[i, j] != WALL and temp_maze[i, j] != SUB_GOAL:  # Only plot actions for non-wall and non-sub-goal cells
                # Skip states where all Q-values are equal (no preferred action)
                    if len(np.unique(q_table[state])) == 1: # Check if all Q-values for this state are equal to each other
                        continue

                    # Determine the best action according to the Q-table
                    action = np.argmax(q_table[state])
                    if action == 0:  # Up
                        ax.arrow(j + 0.4, temp_maze.shape[0] - i - 0.75, 0, 0.3, head_width=0.1, head_length=0.1, fc='black', ec='black')
                    elif action == 1:  # Down
                        ax.arrow(j + 0.4, temp_maze.shape[0] - i - 0.25, 0, -0.3, head_width=0.1, head_length=0.1, fc='black', ec='black')
                    elif action == 2:  # Left
                        ax.arrow(j + 0.75, temp_maze.shape[0] - i - 0.6, -0.3, 0, head_width=0.1, head_length=0.1, fc='black', ec='black')
                    elif action == 3:  # Right
                        ax.arrow(j + 0.25, temp_maze.shape[0] - i - 0.6, 0.3, 0, head_width=0.1, head_length=0.1, fc='black', ec='black')

        # Add red arrows to represent the learned policy for states after subgoal is visited
        for i in range(temp_maze.shape[0]):
            for j in range(temp_maze.shape[1]):
                state = i * temp_maze.shape[1] + j + 100 # Adjust the state index to be after the sub-goal is visited
                if temp_maze[i, j] != WALL and temp_maze[i, j] != END: # Skip walls and the goal
                    # Skip states where all Q-values are equal (no preferred action)
                    if len(np.unique(q_table[state])) == 1:   # Skip if all Q-values are equal
                        continue

                    # Determine the best action according to the Q-table
                    action = np.argmax(q_table[state])
                    if action == 0:  # Up
                        ax.arrow(j + 0.6, temp_maze.shape[0] - i - 0.75, 0, 0.3, head_width=0.1, head_length=0.1, fc='red', ec='red')
                    elif action == 1:  # Down
                        ax.arrow(j + 0.6, temp_maze.shape[0] - i - 0.25, 0, -0.3, head_width=0.1, head_length=0.1, fc='red', ec='red')
                    elif action == 2:  # Left
                        ax.arrow(j + 0.75, temp_maze.shape[0] - i - 0.4, -0.3, 0, head_width=0.1, head_length=0.1, fc='red', ec='red')
                    elif action == 3:  # Right
                        ax.arrow(j + 0.25, temp_maze.shape[0] - i - 0.4, 0.3, 0, head_width=0.1, head_length=0.1, fc='red', ec='red')

        # Set axes limits
        ax.set_xlim(0, temp_maze.shape[1])
        ax.set_ylim(0, temp_maze.shape[0])
        ax.set_aspect('equal')
        ax.set_xticks([]) # Remove x-axis ticks
        ax.set_yticks([]) # Remove y-axis ticks

        plt.title('Learned Policy Visualization') # Set the title
        plt.show() # Show the plot

# %% [markdown]
# #3. Function for Showing the Learned Policy

# %%
def demonstrate_policy(env, q_table):
    """ Demonstrates the agent's policy learned from the Q-table.

    This function simulates the agent's behavior using the policy derived from
    the Q-table. It visualizes the agent's movement through the environment over a
    specified number of steps (or states), rendering the environment's state at each step.

    Args:
        env: The environment instance, which must have `reset`, `step`, and `colorful_render`
             methods (e.g., compatible with OpenAI Gym environments).
        q_table (numpy.ndarray): The Q-table representing the learned state-action values.

    Returns:
        None: This function does not return a value but renders a visual representation
              of the environment for each step taken by the agent.
    """
    # Reset the environment and start from the initial state
    state = env.reset()
    done = False
    num_path_states = 1

    # Calculate the number of states in the optimal path
    while not done:
        num_path_states += 1
        action = np.argmax(q_table[state])
        state, _, done, _ = env.step(action)

    # Reset the environment and start from the initial state
    state = env.reset()
    fig, axes = plt.subplots(1, num_path_states, figsize=(15, 5))

    # Simulate the path based on the action with the maximum value in the q-table until a terminal state is reached
    for i in range(num_path_states):
        env.colorful_render(ax=axes[i])
        action = np.argmax(q_table[state])
        state, _, done, _ = env.step(action)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 4. Tabular Q-Learning Algorithm

# %%
def q_learning(env, episodes, alpha=0.1, gamma=0.95, epsilon=0.45, convergence_window=50, threshold=0.01, optimize = False):
    """ Q-learning algorithm for training the agent in the maze environment, with convergence tracking and timer.

    Args:
        env: The maze environment instance.
        episodes (int): Number of episodes to train the agent.
        alpha (float): Learning rate (0 < alpha <= 1).
        gamma (float): Discount factor (0 <= gamma < 1).
        epsilon (float): Exploration rate (0 <= epsilon <= 1).
        convergence_window (int): Number of episodes to average rewards over to determine convergence.
        threshold (float): Minimum difference in average rewards between windows to determine convergence.

    Returns:
        tuple: (Q-table, total rewards, steps per episode, episodes until convergence, time taken)
    """
    start_time = time.time()  # Start the timer

    q_table = np.zeros([env.observation_space.n, env.action_space.n])  # Initialize Q-table with all zeros
    total_rewards = []
    steps_per_episode = []
    convergence_episode = episodes  # Default to total episodes if convergence isn't reached

    for episode in range(episodes):
        state = env.reset()  # Start a new episode and get the initial state
        done = False
        steps = 0
        total_reward = 0
        end_time = None

        while not done:
            # Select action using epsilon-greedy strategy
            if rng.uniform(0, 1) < epsilon:
                action = env.action_space.sample()  # Explore: choose a random action
            else:
                action = np.argmax(q_table[state])  # Exploit: choose the best known action based on current Q-table

            # Take the action and observe the new state and reward
            new_state, reward, done, _ = env.step(action)
            total_reward += reward
            steps += 1

            # Update the Q-table using the Bellman equation
            best_next_action = np.argmax(q_table[new_state])  # Best action from the new state
            td_target = reward + gamma * q_table[new_state][best_next_action]
            td_error = td_target - q_table[state][action]
            q_table[state][action] += alpha * td_error  # Update the Q-value

            # Move to the next state
            state = new_state

        total_rewards.append(total_reward)
        steps_per_episode.append(steps)

        # For optimization of convergence speed, check for convergence every episode after the sliding window has been filled twice
        if episode >= convergence_window*2:
            avg_recent_reward = np.mean(total_rewards[episode - convergence_window:episode])
            avg_previous_reward = np.mean(total_rewards[episode - 2*convergence_window:episode - convergence_window])

            # If the difference between average rewards in two consecutive windows is below threshold, we've converged
            if abs(avg_recent_reward - avg_previous_reward) < threshold:
                if convergence_episode == episodes:
                  convergence_episode = episode
                  end_time = time.time() # End the timer
                  if optimize == True:
                      break

    if end_time == None:
        end_time = time.time() # End the timer in case convergence has not been reached
    learning_time = end_time - start_time  # Calculate the total time taken

    return q_table, total_rewards, steps_per_episode, convergence_episode, learning_time

# %% [markdown]
# ##4.1 Function for Plotting the Cumulative Reward and Steps per Episode for the Q-Learning Algorithm

# %%
def plot_metrics(total_rewards, steps_per_episode):
    """Plots the total rewards and steps taken per episode during Q-learning training.

    This function generates two subplots to visualize the learning performance of the agent:
    - Total rewards accumulated per episode.
    - Number of steps taken per episode.

    Args:
        total_rewards (list or numpy.ndarray): A list or array of total rewards obtained by the agent in each episode.
        steps_per_episode (list or numpy.ndarray): A list or array of the number of steps the agent took in each episode.

    Returns:
        None: This function does not return a value but displays the plots showing learning metrics.
    """
    # Create a figure
    plt.figure(figsize=(10, 4))

    # Plot total rewards per episode on the first subplot
    plt.subplot(1, 2, 1)
    plt.plot(total_rewards)

    # Set x-ticks and y-ticks for better readability
    plt.xticks(np.arange(0, len(total_rewards), step=20))
    plt.yticks(np.arange(min(total_rewards), max(total_rewards), step=10))

    # Set the title
    plt.title('Cumulative Reward per Episode')
    # Set the labels of the axes
    plt.xlabel('Episode')
    plt.ylabel('Cumulative Reward')
    # Add gridlines to the plot
    plt.grid(True)

    # Plot steps taken per episode on the second subplot
    plt.subplot(1, 2, 2)
    plt.plot(steps_per_episode)

    # Set x-ticks and y-ticks for better readability
    plt.xticks(np.arange(0, len(steps_per_episode), step=20)) # update for the x-axis (change step for more or less values on the axes)
    plt.yticks(np.arange(0, max(steps_per_episode), step=20)) # update for the y-axis (change step for more or less values on the axes)

    # Set the title
    plt.title('Steps Taken per Episode')
    # Set the labels of the axes
    plt.xlabel('Episode')
    plt.ylabel('Steps')
    # Add gridlines to the plot
    plt.grid(True)

    # Show the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 4.2. Function for Finding the Value of Epsilon Leading to Fastest Convergence

# %%
env_with_subgoal = MazeEnv()

def objective(trial):
    """Objective function for optimizing the epsilon parameter in the Q-learning algorithm.

    This function optimizes the exploration rate (epsilon) based on how quickly
    the agent converges to an optimal policy in a maze environment.

    Args:
        trial (optuna.trial.Trial): The trial object provided by Optuna to suggest epsilon.

    Returns:
        float: The number of episodes taken to converge, where fewer episodes indicate faster convergence.
    """
    # Suggest a value for epsilon in the range [0.01, 1.0]
    epsilon = trial.suggest_float('epsilon', 0.01, 0.99, step=0.01)

    # You can modify episodes as needed
    episodes = 1000
    convergence_window = 50  # Size of sliding window to check for convergence
    threshold = 0.01         # Threshold for detecting when reward has stabilized

    # Call your Q-learning function
    _, total_rewards, _, convergence_episode, _ = q_learning(
        env_with_subgoal, episodes, alpha=0.1, gamma=0.95,
        epsilon=epsilon, convergence_window=convergence_window, threshold=threshold, optimize=True)

    # We want to minimize the number of episodes until convergence
    return convergence_episode

# %% [markdown]
# ###4.2.1. Finding the Value of Epsilon Leading to Fastest Convergence

# %%
# Create an Optuna study with a seed for reproducibility
sampler = optuna.samplers.TPESampler(seed=random_seed)
study = optuna.create_study(direction='minimize', sampler=sampler)

# Run the optimization
study.optimize(objective, n_trials=1000)  # Adjust n_trials as needed

# Print the best epsilon and the corresponding number of episodes to converge
print(f"Best epsilon value: {study.best_params['epsilon']}")
print(f"Best number of episodes to converge: {study.best_value}")
# Out:
# [I 2024-10-26 16:29:47,781] A new study created in memory with name: no-name-3deecee4-d67b-4696-8d51-c0f08e9f4d0e
# [I 2024-10-26 16:29:49,113] Trial 0 finished with value: 376.0 and parameters: {'epsilon': 0.87}. Best is trial 0 with value: 376.0.
# [I 2024-10-26 16:29:49,525] Trial 1 finished with value: 337.0 and parameters: {'epsilon': 0.5800000000000001}. Best is trial 1 with value: 337.0.
# [I 2024-10-26 16:29:49,696] Trial 2 finished with value: 164.0 and parameters: {'epsilon': 0.28}. Best is trial 2 with value: 164.0.
# [I 2024-10-26 16:29:49,838] Trial 3 finished with value: 223.0 and parameters: {'epsilon': 0.19}. Best is trial 2 with value: 164.0.
# [I 2024-10-26 16:29:49,985] Trial 4 finished with value: 161.0 and parameters: {'epsilon': 0.41000000000000003}. Best is trial 4 with value: 161.0.
# [I 2024-10-26 16:29:50,129] Trial 5 finished with value: 212.0 and parameters: {'epsilon': 0.12}. Best is trial 4 with value: 161.0.
# [I 2024-10-26 16:29:52,369] Trial 6 finished with value: 1000.0 and parameters: {'epsilon': 0.68}. Best is trial 4 with value: 161.0.
# [I 2024-10-26 16:29:52,853] Trial 7 finished with value: 236.0 and parameters: {'epsilon': 0.44}. Best is trial 4 with value: 161.0.
# [I 2024-10-26 16:29:53,543] Trial 8 finished with value: 328.0 and parameters: {'epsilon': 0.56}. Best is trial 4 with value: 161.0.
# [I 2024-10-26 16:29:53,834] Trial 9 finished with value: 141.0 and parameters: {'epsilon': 0.37}. Best is trial 9 with value: 141.0.
# [I 2024-10-26 16:29:54,100] Trial 10 finished with value: 198.0 and parameters: {'epsilon': 0.05}. Best is trial 9 with value: 141.0.
# [I 2024-10-26 16:29:54,462] Trial 11 finished with value: 148.0 and parameters: {'epsilon': 0.37}. Best is trial 9 with value: 141.0.
# [I 2024-10-26 16:29:54,751] Trial 12 finished with value: 145.0 and parameters: {'epsilon': 0.3}. Best is trial 9 with value: 141.0.
# [I 2024-10-26 16:29:54,979] Trial 13 finished with value: 136.0 and parameters: {'epsilon': 0.24000000000000002}. Best is trial 13 with value: 136.0.
# [I 2024-10-26 16:29:55,227] Trial 14 finished with value: 127.0 and parameters: {'epsilon': 0.23}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:55,468] Trial 15 finished with value: 158.0 and parameters: {'epsilon': 0.02}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:55,767] Trial 16 finished with value: 198.0 and parameters: {'epsilon': 0.25}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:55,877] Trial 17 finished with value: 149.0 and parameters: {'epsilon': 0.16}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:57,819] Trial 18 finished with value: 580.0 and parameters: {'epsilon': 0.81}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:58,231] Trial 19 finished with value: 270.0 and parameters: {'epsilon': 0.51}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:58,368] Trial 20 finished with value: 180.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:58,707] Trial 21 finished with value: 317.0 and parameters: {'epsilon': 0.34}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:58,946] Trial 22 finished with value: 255.0 and parameters: {'epsilon': 0.22}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:59,152] Trial 23 finished with value: 161.0 and parameters: {'epsilon': 0.45}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:59,515] Trial 24 finished with value: 339.0 and parameters: {'epsilon': 0.33}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:29:59,979] Trial 25 finished with value: 170.0 and parameters: {'epsilon': 0.6900000000000001}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:00,305] Trial 26 finished with value: 203.0 and parameters: {'epsilon': 0.21000000000000002}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:00,515] Trial 27 finished with value: 181.0 and parameters: {'epsilon': 0.12}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:10,037] Trial 28 finished with value: 1000.0 and parameters: {'epsilon': 0.98}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:10,124] Trial 29 finished with value: 174.0 and parameters: {'epsilon': 0.38}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:10,290] Trial 30 finished with value: 330.0 and parameters: {'epsilon': 0.51}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:10,414] Trial 31 finished with value: 315.0 and parameters: {'epsilon': 0.28}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:10,498] Trial 32 finished with value: 192.0 and parameters: {'epsilon': 0.32}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:10,557] Trial 33 finished with value: 127.0 and parameters: {'epsilon': 0.27}. Best is trial 14 with value: 127.0.
# [I 2024-10-26 16:30:10,607] Trial 34 finished with value: 121.0 and parameters: {'epsilon': 0.17}. Best is trial 34 with value: 121.0.
# [I 2024-10-26 16:30:10,695] Trial 35 finished with value: 263.0 and parameters: {'epsilon': 0.17}. Best is trial 34 with value: 121.0.
# [I 2024-10-26 16:30:10,769] Trial 36 finished with value: 164.0 and parameters: {'epsilon': 0.25}. Best is trial 34 with value: 121.0.
# [I 2024-10-26 16:30:10,821] Trial 37 finished with value: 125.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 34 with value: 121.0.
# [I 2024-10-26 16:30:10,866] Trial 38 finished with value: 119.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:10,915] Trial 39 finished with value: 127.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:10,979] Trial 40 finished with value: 141.0 and parameters: {'epsilon': 0.03}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,060] Trial 41 finished with value: 150.0 and parameters: {'epsilon': 0.13}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,117] Trial 42 finished with value: 155.0 and parameters: {'epsilon': 0.08}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,194] Trial 43 finished with value: 196.0 and parameters: {'epsilon': 0.17}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,252] Trial 44 finished with value: 145.0 and parameters: {'epsilon': 0.14}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,310] Trial 45 finished with value: 151.0 and parameters: {'epsilon': 0.02}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,362] Trial 46 finished with value: 123.0 and parameters: {'epsilon': 0.09}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,416] Trial 47 finished with value: 138.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,469] Trial 48 finished with value: 156.0 and parameters: {'epsilon': 0.01}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,523] Trial 49 finished with value: 129.0 and parameters: {'epsilon': 0.19}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,585] Trial 50 finished with value: 166.0 and parameters: {'epsilon': 0.11}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,657] Trial 51 finished with value: 136.0 and parameters: {'epsilon': 0.2}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,716] Trial 52 finished with value: 162.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,773] Trial 53 finished with value: 135.0 and parameters: {'epsilon': 0.15000000000000002}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,829] Trial 54 finished with value: 145.0 and parameters: {'epsilon': 0.09}. Best is trial 38 with value: 119.0.
# [I 2024-10-26 16:30:11,885] Trial 55 finished with value: 118.0 and parameters: {'epsilon': 0.26}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,047] Trial 56 finished with value: 167.0 and parameters: {'epsilon': 0.66}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,101] Trial 57 finished with value: 121.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,147] Trial 58 finished with value: 118.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,200] Trial 59 finished with value: 122.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,249] Trial 60 finished with value: 122.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,308] Trial 61 finished with value: 168.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,358] Trial 62 finished with value: 128.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,416] Trial 63 finished with value: 139.0 and parameters: {'epsilon': 0.12}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,462] Trial 64 finished with value: 119.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,547] Trial 65 finished with value: 266.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,611] Trial 66 finished with value: 177.0 and parameters: {'epsilon': 0.11}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,660] Trial 67 finished with value: 119.0 and parameters: {'epsilon': 0.15000000000000002}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,718] Trial 68 finished with value: 150.0 and parameters: {'epsilon': 0.18000000000000002}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,777] Trial 69 finished with value: 145.0 and parameters: {'epsilon': 0.15000000000000002}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,858] Trial 70 finished with value: 121.0 and parameters: {'epsilon': 0.23}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:12,940] Trial 71 finished with value: 215.0 and parameters: {'epsilon': 0.23}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,080] Trial 72 finished with value: 215.0 and parameters: {'epsilon': 0.44}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,209] Trial 73 finished with value: 316.0 and parameters: {'epsilon': 0.27}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,271] Trial 74 finished with value: 151.0 and parameters: {'epsilon': 0.21000000000000002}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,333] Trial 75 finished with value: 130.0 and parameters: {'epsilon': 0.3}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,385] Trial 76 finished with value: 132.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,490] Trial 77 finished with value: 320.0 and parameters: {'epsilon': 0.14}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,546] Trial 78 finished with value: 155.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,622] Trial 79 finished with value: 158.0 and parameters: {'epsilon': 0.36000000000000004}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,693] Trial 80 finished with value: 182.0 and parameters: {'epsilon': 0.17}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,759] Trial 81 finished with value: 158.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,835] Trial 82 finished with value: 243.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:13,920] Trial 83 finished with value: 273.0 and parameters: {'epsilon': 0.09}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:14,015] Trial 84 finished with value: 241.0 and parameters: {'epsilon': 0.13}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:14,079] Trial 85 finished with value: 144.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:14,153] Trial 86 finished with value: 168.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:15,481] Trial 87 finished with value: 934.0 and parameters: {'epsilon': 0.8200000000000001}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:15,624] Trial 88 finished with value: 292.0 and parameters: {'epsilon': 0.47000000000000003}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:15,738] Trial 89 finished with value: 272.0 and parameters: {'epsilon': 0.25}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:15,799] Trial 90 finished with value: 151.0 and parameters: {'epsilon': 0.11}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:15,851] Trial 91 finished with value: 124.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:15,903] Trial 92 finished with value: 122.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:15,986] Trial 93 finished with value: 233.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,044] Trial 94 finished with value: 137.0 and parameters: {'epsilon': 0.09}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,096] Trial 95 finished with value: 123.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,179] Trial 96 finished with value: 189.0 and parameters: {'epsilon': 0.19}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,237] Trial 97 finished with value: 161.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,296] Trial 98 finished with value: 159.0 and parameters: {'epsilon': 0.14}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,448] Trial 99 finished with value: 272.0 and parameters: {'epsilon': 0.54}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,530] Trial 100 finished with value: 244.0 and parameters: {'epsilon': 0.12}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,580] Trial 101 finished with value: 134.0 and parameters: {'epsilon': 0.02}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,635] Trial 102 finished with value: 126.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,703] Trial 103 finished with value: 138.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:16,757] Trial 104 finished with value: 124.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,252] Trial 105 finished with value: 795.0 and parameters: {'epsilon': 0.61}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,311] Trial 106 finished with value: 167.0 and parameters: {'epsilon': 0.09}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,377] Trial 107 finished with value: 161.0 and parameters: {'epsilon': 0.16}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,429] Trial 108 finished with value: 142.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,514] Trial 109 finished with value: 193.0 and parameters: {'epsilon': 0.3}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,625] Trial 110 finished with value: 245.0 and parameters: {'epsilon': 0.22}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,682] Trial 111 finished with value: 129.0 and parameters: {'epsilon': 0.09}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,729] Trial 112 finished with value: 119.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,778] Trial 113 finished with value: 122.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,844] Trial 114 finished with value: 200.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,907] Trial 115 finished with value: 163.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:17,963] Trial 116 finished with value: 128.0 and parameters: {'epsilon': 0.02}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:18,050] Trial 117 finished with value: 198.0 and parameters: {'epsilon': 0.11}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:22,868] Trial 118 finished with value: 1000.0 and parameters: {'epsilon': 0.97}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:22,943] Trial 119 finished with value: 233.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,004] Trial 120 finished with value: 156.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,060] Trial 121 finished with value: 132.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,131] Trial 122 finished with value: 223.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,187] Trial 123 finished with value: 131.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,237] Trial 124 finished with value: 118.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,339] Trial 125 finished with value: 215.0 and parameters: {'epsilon': 0.4}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,400] Trial 126 finished with value: 165.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,463] Trial 127 finished with value: 177.0 and parameters: {'epsilon': 0.08}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,561] Trial 128 finished with value: 238.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,636] Trial 129 finished with value: 173.0 and parameters: {'epsilon': 0.25}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,693] Trial 130 finished with value: 143.0 and parameters: {'epsilon': 0.12}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,747] Trial 131 finished with value: 135.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,802] Trial 132 finished with value: 126.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,854] Trial 133 finished with value: 119.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,912] Trial 134 finished with value: 145.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:23,990] Trial 135 finished with value: 148.0 and parameters: {'epsilon': 0.2}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,072] Trial 136 finished with value: 212.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,132] Trial 137 finished with value: 158.0 and parameters: {'epsilon': 0.08}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,189] Trial 138 finished with value: 130.0 and parameters: {'epsilon': 0.15000000000000002}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,249] Trial 139 finished with value: 174.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,310] Trial 140 finished with value: 153.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,368] Trial 141 finished with value: 146.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,461] Trial 142 finished with value: 328.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,526] Trial 143 finished with value: 157.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,641] Trial 144 finished with value: 281.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,715] Trial 145 finished with value: 170.0 and parameters: {'epsilon': 0.08}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,773] Trial 146 finished with value: 150.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,837] Trial 147 finished with value: 165.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,896] Trial 148 finished with value: 156.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:24,967] Trial 149 finished with value: 141.0 and parameters: {'epsilon': 0.17}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,041] Trial 150 finished with value: 133.0 and parameters: {'epsilon': 0.13}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,098] Trial 151 finished with value: 128.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,151] Trial 152 finished with value: 120.0 and parameters: {'epsilon': 0.08}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,201] Trial 153 finished with value: 125.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,260] Trial 154 finished with value: 161.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,316] Trial 155 finished with value: 149.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,370] Trial 156 finished with value: 130.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,452] Trial 157 finished with value: 249.0 and parameters: {'epsilon': 0.08}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,509] Trial 158 finished with value: 154.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,576] Trial 159 finished with value: 156.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,653] Trial 160 finished with value: 151.0 and parameters: {'epsilon': 0.11}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,717] Trial 161 finished with value: 165.0 and parameters: {'epsilon': 0.09}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,771] Trial 162 finished with value: 129.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,836] Trial 163 finished with value: 189.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,903] Trial 164 finished with value: 145.0 and parameters: {'epsilon': 0.13}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:25,960] Trial 165 finished with value: 128.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,039] Trial 166 finished with value: 146.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,099] Trial 167 finished with value: 126.0 and parameters: {'epsilon': 0.23}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,161] Trial 168 finished with value: 146.0 and parameters: {'epsilon': 0.19}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,231] Trial 169 finished with value: 178.0 and parameters: {'epsilon': 0.08}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,282] Trial 170 finished with value: 126.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,337] Trial 171 finished with value: 122.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,409] Trial 172 finished with value: 224.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,460] Trial 173 finished with value: 120.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,524] Trial 174 finished with value: 151.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:26,578] Trial 175 finished with value: 144.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,048] Trial 176 finished with value: 476.0 and parameters: {'epsilon': 0.72}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,129] Trial 177 finished with value: 255.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,191] Trial 178 finished with value: 168.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,253] Trial 179 finished with value: 168.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,308] Trial 180 finished with value: 145.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,380] Trial 181 finished with value: 224.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,449] Trial 182 finished with value: 170.0 and parameters: {'epsilon': 0.09}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,503] Trial 183 finished with value: 146.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,578] Trial 184 finished with value: 217.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,633] Trial 185 finished with value: 119.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,696] Trial 186 finished with value: 153.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,748] Trial 187 finished with value: 129.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,813] Trial 188 finished with value: 125.0 and parameters: {'epsilon': 0.04}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,876] Trial 189 finished with value: 165.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:27,932] Trial 190 finished with value: 135.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,004] Trial 191 finished with value: 120.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,072] Trial 192 finished with value: 161.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,121] Trial 193 finished with value: 119.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,174] Trial 194 finished with value: 141.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,236] Trial 195 finished with value: 141.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,296] Trial 196 finished with value: 144.0 and parameters: {'epsilon': 0.05}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,346] Trial 197 finished with value: 124.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,422] Trial 198 finished with value: 210.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,487] Trial 199 finished with value: 151.0 and parameters: {'epsilon': 0.21000000000000002}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,565] Trial 200 finished with value: 155.0 and parameters: {'epsilon': 0.26}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,614] Trial 201 finished with value: 128.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,756] Trial 202 finished with value: 269.0 and parameters: {'epsilon': 0.29000000000000004}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,809] Trial 203 finished with value: 121.0 and parameters: {'epsilon': 0.03}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,900] Trial 204 finished with value: 194.0 and parameters: {'epsilon': 0.34}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:28,958] Trial 205 finished with value: 138.0 and parameters: {'epsilon': 0.01}. Best is trial 55 with value: 118.0.
# [I 2024-10-26 16:30:29,026] Trial 206 finished with value: 115.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,086] Trial 207 finished with value: 156.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,155] Trial 208 finished with value: 152.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,218] Trial 209 finished with value: 137.0 and parameters: {'epsilon': 0.11}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,273] Trial 210 finished with value: 128.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,353] Trial 211 finished with value: 219.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,404] Trial 212 finished with value: 125.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,499] Trial 213 finished with value: 307.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,562] Trial 214 finished with value: 121.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,632] Trial 215 finished with value: 199.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,693] Trial 216 finished with value: 126.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,756] Trial 217 finished with value: 132.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,820] Trial 218 finished with value: 178.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,883] Trial 219 finished with value: 144.0 and parameters: {'epsilon': 0.16}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:29,946] Trial 220 finished with value: 160.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,013] Trial 221 finished with value: 124.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,070] Trial 222 finished with value: 120.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,125] Trial 223 finished with value: 145.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,196] Trial 224 finished with value: 202.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,246] Trial 225 finished with value: 119.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,349] Trial 226 finished with value: 164.0 and parameters: {'epsilon': 0.48000000000000004}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,404] Trial 227 finished with value: 125.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,476] Trial 228 finished with value: 217.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,557] Trial 229 finished with value: 182.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,640] Trial 230 finished with value: 241.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,703] Trial 231 finished with value: 145.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,771] Trial 232 finished with value: 129.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,831] Trial 233 finished with value: 165.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,885] Trial 234 finished with value: 125.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:30,940] Trial 235 finished with value: 129.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,011] Trial 236 finished with value: 130.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,079] Trial 237 finished with value: 133.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,130] Trial 238 finished with value: 130.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,191] Trial 239 finished with value: 144.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,241] Trial 240 finished with value: 118.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,301] Trial 241 finished with value: 143.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,363] Trial 242 finished with value: 182.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,434] Trial 243 finished with value: 209.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,489] Trial 244 finished with value: 122.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,550] Trial 245 finished with value: 158.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,600] Trial 246 finished with value: 126.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,656] Trial 247 finished with value: 138.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,737] Trial 248 finished with value: 249.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,829] Trial 249 finished with value: 210.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:31,917] Trial 250 finished with value: 241.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,010] Trial 251 finished with value: 176.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,210] Trial 252 finished with value: 338.0 and parameters: {'epsilon': 0.18000000000000002}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,345] Trial 253 finished with value: 198.0 and parameters: {'epsilon': 0.23}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,459] Trial 254 finished with value: 197.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,543] Trial 255 finished with value: 125.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,642] Trial 256 finished with value: 157.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,731] Trial 257 finished with value: 127.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,825] Trial 258 finished with value: 141.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:32,916] Trial 259 finished with value: 133.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,079] Trial 260 finished with value: 180.0 and parameters: {'epsilon': 0.41000000000000003}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,161] Trial 261 finished with value: 123.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,324] Trial 262 finished with value: 234.0 and parameters: {'epsilon': 0.31}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,432] Trial 263 finished with value: 188.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,541] Trial 264 finished with value: 163.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,640] Trial 265 finished with value: 134.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,758] Trial 266 finished with value: 142.0 and parameters: {'epsilon': 0.14}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,873] Trial 267 finished with value: 130.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:33,981] Trial 268 finished with value: 177.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,120] Trial 269 finished with value: 130.0 and parameters: {'epsilon': 0.28}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,228] Trial 270 finished with value: 162.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,347] Trial 271 finished with value: 179.0 and parameters: {'epsilon': 0.11}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,433] Trial 272 finished with value: 117.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,528] Trial 273 finished with value: 136.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,715] Trial 274 finished with value: 136.0 and parameters: {'epsilon': 0.6}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,810] Trial 275 finished with value: 122.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:34,918] Trial 276 finished with value: 145.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,022] Trial 277 finished with value: 196.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,083] Trial 278 finished with value: 149.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,183] Trial 279 finished with value: 138.0 and parameters: {'epsilon': 0.54}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,482] Trial 280 finished with value: 253.0 and parameters: {'epsilon': 0.76}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,541] Trial 281 finished with value: 124.0 and parameters: {'epsilon': 0.2}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,601] Trial 282 finished with value: 164.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,771] Trial 283 finished with value: 339.0 and parameters: {'epsilon': 0.37}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,828] Trial 284 finished with value: 139.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,885] Trial 285 finished with value: 136.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:35,940] Trial 286 finished with value: 127.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,059] Trial 287 finished with value: 243.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,155] Trial 288 finished with value: 281.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,237] Trial 289 finished with value: 264.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,291] Trial 290 finished with value: 125.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,356] Trial 291 finished with value: 141.0 and parameters: {'epsilon': 0.12}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,748] Trial 292 finished with value: 202.0 and parameters: {'epsilon': 0.87}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,798] Trial 293 finished with value: 121.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,859] Trial 294 finished with value: 122.0 and parameters: {'epsilon': 0.24000000000000002}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:36,920] Trial 295 finished with value: 140.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,001] Trial 296 finished with value: 190.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,074] Trial 297 finished with value: 134.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,127] Trial 298 finished with value: 127.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,189] Trial 299 finished with value: 131.0 and parameters: {'epsilon': 0.17}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,267] Trial 300 finished with value: 209.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,322] Trial 301 finished with value: 139.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,382] Trial 302 finished with value: 137.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,437] Trial 303 finished with value: 121.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,491] Trial 304 finished with value: 123.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,557] Trial 305 finished with value: 142.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,636] Trial 306 finished with value: 168.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,694] Trial 307 finished with value: 120.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,760] Trial 308 finished with value: 176.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,815] Trial 309 finished with value: 119.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,877] Trial 310 finished with value: 143.0 and parameters: {'epsilon': 0.14}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:37,965] Trial 311 finished with value: 217.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,064] Trial 312 finished with value: 183.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,127] Trial 313 finished with value: 164.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,195] Trial 314 finished with value: 185.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,309] Trial 315 finished with value: 196.0 and parameters: {'epsilon': 0.44}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,370] Trial 316 finished with value: 164.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,431] Trial 317 finished with value: 166.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,483] Trial 318 finished with value: 119.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,562] Trial 319 finished with value: 152.0 and parameters: {'epsilon': 0.26}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,634] Trial 320 finished with value: 140.0 and parameters: {'epsilon': 0.22}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,704] Trial 321 finished with value: 195.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,758] Trial 322 finished with value: 127.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,833] Trial 323 finished with value: 190.0 and parameters: {'epsilon': 0.12}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:38,911] Trial 324 finished with value: 194.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,008] Trial 325 finished with value: 228.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,062] Trial 326 finished with value: 118.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,142] Trial 327 finished with value: 179.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,200] Trial 328 finished with value: 143.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,257] Trial 329 finished with value: 131.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,322] Trial 330 finished with value: 171.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,450] Trial 331 finished with value: 150.0 and parameters: {'epsilon': 0.66}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,521] Trial 332 finished with value: 136.0 and parameters: {'epsilon': 0.19}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,574] Trial 333 finished with value: 121.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,635] Trial 334 finished with value: 120.0 and parameters: {'epsilon': 0.15000000000000002}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,703] Trial 335 finished with value: 171.0 and parameters: {'epsilon': 0.13}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,777] Trial 336 finished with value: 150.0 and parameters: {'epsilon': 0.16}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,865] Trial 337 finished with value: 262.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:39,976] Trial 338 finished with value: 276.0 and parameters: {'epsilon': 0.15000000000000002}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:40,043] Trial 339 finished with value: 124.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:40,108] Trial 340 finished with value: 129.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:40,178] Trial 341 finished with value: 147.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:40,240] Trial 342 finished with value: 133.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:30:40,294] Trial 343 finished with value: 126.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# ...
# [I 2024-10-26 16:31:42,089] Trial 887 finished with value: 158.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,167] Trial 888 finished with value: 153.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,239] Trial 889 finished with value: 147.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,303] Trial 890 finished with value: 128.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,396] Trial 891 finished with value: 179.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,472] Trial 892 finished with value: 161.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,539] Trial 893 finished with value: 120.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,609] Trial 894 finished with value: 123.0 and parameters: {'epsilon': 0.13}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,680] Trial 895 finished with value: 142.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,766] Trial 896 finished with value: 172.0 and parameters: {'epsilon': 0.22}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,836] Trial 897 finished with value: 122.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:42,915] Trial 898 finished with value: 157.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,019] Trial 899 finished with value: 222.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,090] Trial 900 finished with value: 124.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,162] Trial 901 finished with value: 128.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,246] Trial 902 finished with value: 215.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,310] Trial 903 finished with value: 125.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,406] Trial 904 finished with value: 188.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,496] Trial 905 finished with value: 181.0 and parameters: {'epsilon': 0.19}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,579] Trial 906 finished with value: 198.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,669] Trial 907 finished with value: 203.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,752] Trial 908 finished with value: 151.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:43,826] Trial 909 finished with value: 174.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,241] Trial 910 finished with value: 600.0 and parameters: {'epsilon': 0.63}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,310] Trial 911 finished with value: 134.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,389] Trial 912 finished with value: 191.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,475] Trial 913 finished with value: 154.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,728] Trial 914 finished with value: 434.0 and parameters: {'epsilon': 0.48000000000000004}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,812] Trial 915 finished with value: 187.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,878] Trial 916 finished with value: 124.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:44,949] Trial 917 finished with value: 125.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,028] Trial 918 finished with value: 132.0 and parameters: {'epsilon': 0.15000000000000002}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,094] Trial 919 finished with value: 123.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,174] Trial 920 finished with value: 170.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,251] Trial 921 finished with value: 142.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,321] Trial 922 finished with value: 152.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,392] Trial 923 finished with value: 135.0 and parameters: {'epsilon': 0.12}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,476] Trial 924 finished with value: 141.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,552] Trial 925 finished with value: 155.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,663] Trial 926 finished with value: 154.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,730] Trial 927 finished with value: 124.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,848] Trial 928 finished with value: 366.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:45,924] Trial 929 finished with value: 161.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:46,027] Trial 930 finished with value: 197.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:46,096] Trial 931 finished with value: 134.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:46,170] Trial 932 finished with value: 148.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:46,234] Trial 933 finished with value: 121.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:46,885] Trial 934 finished with value: 536.0 and parameters: {'epsilon': 0.77}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:46,962] Trial 935 finished with value: 131.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,029] Trial 936 finished with value: 122.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,157] Trial 937 finished with value: 203.0 and parameters: {'epsilon': 0.41000000000000003}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,247] Trial 938 finished with value: 223.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,313] Trial 939 finished with value: 128.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,375] Trial 940 finished with value: 120.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,446] Trial 941 finished with value: 136.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,526] Trial 942 finished with value: 138.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,603] Trial 943 finished with value: 164.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,670] Trial 944 finished with value: 119.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,735] Trial 945 finished with value: 129.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,801] Trial 946 finished with value: 122.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:47,974] Trial 947 finished with value: 260.0 and parameters: {'epsilon': 0.5}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,058] Trial 948 finished with value: 162.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,125] Trial 949 finished with value: 119.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,203] Trial 950 finished with value: 133.0 and parameters: {'epsilon': 0.12}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,279] Trial 951 finished with value: 140.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,356] Trial 952 finished with value: 185.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,425] Trial 953 finished with value: 134.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,534] Trial 954 finished with value: 275.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,623] Trial 955 finished with value: 202.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,688] Trial 956 finished with value: 120.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,808] Trial 957 finished with value: 142.0 and parameters: {'epsilon': 0.31}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,880] Trial 958 finished with value: 145.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:48,971] Trial 959 finished with value: 200.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,051] Trial 960 finished with value: 122.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,119] Trial 961 finished with value: 122.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,207] Trial 962 finished with value: 195.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,279] Trial 963 finished with value: 123.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,364] Trial 964 finished with value: 209.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,430] Trial 965 finished with value: 123.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,509] Trial 966 finished with value: 194.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,639] Trial 967 finished with value: 174.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:49,773] Trial 968 finished with value: 153.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:50,079] Trial 969 finished with value: 184.0 and parameters: {'epsilon': 0.67}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:50,193] Trial 970 finished with value: 122.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:50,311] Trial 971 finished with value: 141.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:50,427] Trial 972 finished with value: 140.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:50,543] Trial 973 finished with value: 122.0 and parameters: {'epsilon': 0.11}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,025] Trial 974 finished with value: 179.0 and parameters: {'epsilon': 0.8300000000000001}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,144] Trial 975 finished with value: 136.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,264] Trial 976 finished with value: 123.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,374] Trial 977 finished with value: 118.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,506] Trial 978 finished with value: 183.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,674] Trial 979 finished with value: 178.0 and parameters: {'epsilon': 0.24000000000000002}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,799] Trial 980 finished with value: 122.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:51,917] Trial 981 finished with value: 122.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,057] Trial 982 finished with value: 120.0 and parameters: {'epsilon': 0.08}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,194] Trial 983 finished with value: 143.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,323] Trial 984 finished with value: 170.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,463] Trial 985 finished with value: 178.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,598] Trial 986 finished with value: 250.0 and parameters: {'epsilon': 0.13}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,667] Trial 987 finished with value: 150.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,763] Trial 988 finished with value: 124.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,832] Trial 989 finished with value: 125.0 and parameters: {'epsilon': 0.09999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:52,899] Trial 990 finished with value: 122.0 and parameters: {'epsilon': 0.060000000000000005}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,010] Trial 991 finished with value: 211.0 and parameters: {'epsilon': 0.16}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,080] Trial 992 finished with value: 122.0 and parameters: {'epsilon': 0.02}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,151] Trial 993 finished with value: 131.0 and parameters: {'epsilon': 0.04}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,227] Trial 994 finished with value: 138.0 and parameters: {'epsilon': 0.09}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,300] Trial 995 finished with value: 138.0 and parameters: {'epsilon': 0.06999999999999999}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,371] Trial 996 finished with value: 126.0 and parameters: {'epsilon': 0.03}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,460] Trial 997 finished with value: 152.0 and parameters: {'epsilon': 0.28}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,555] Trial 998 finished with value: 217.0 and parameters: {'epsilon': 0.01}. Best is trial 206 with value: 115.0.
# [I 2024-10-26 16:31:53,655] Trial 999 finished with value: 206.0 and parameters: {'epsilon': 0.05}. Best is trial 206 with value: 115.0.
# Best epsilon value: 0.05
# Best number of episodes to converge: 115.0

# %% [markdown]
# ## 4.3. Application of the Q-Learning Algorithm to the Maze with Sub-goal

# %% [markdown]
# ###4.3.1. Policy Learned by the Q-Learning Algorithm with Random Epsilon Value

# %%
# Initialize the environment
env_with_subgoal = MazeEnv()

# Train the agent
q_table, total_rewards, steps_per_episode, convergence_episode, learning_time = q_learning(env_with_subgoal, episodes=250, alpha=0.1, gamma=0.95,
                                                                              epsilon=0.45, convergence_window=50, threshold=0.01)

# Show the agent navigating the maze
demonstrate_policy(env_with_subgoal, q_table)

# %% [markdown]
# ###4.3.2. Visualization of the Full Policy Learned by the Q-Learning Algorithm with Random Epsilon Value

# %%
# Visualize the learned policy
env_with_subgoal.visualize_policy(q_table)

# %% [markdown]
# ###4.3.3. Plots of Cumulative Reward and Steps per Episode with Random Epsilon Value

# %%
# Plot cumulative reward and steps over the number of episodes
plot_metrics(total_rewards, steps_per_episode)

# %% [markdown]
# ### 4.3.4. The Convergence Episode & The Time Required for Convergence with Random Epsilon Value

# %%
# Print the convergence episode
print(f"Episode of convergence: {convergence_episode}")
# Print the time required for convergence
print(f"Time required for convergence: {learning_time:.4f} seconds")
# Out:
# Episode of convergence: 208
# Time required for convergence: 0.1317 seconds

# %% [markdown]
# ###4.3.5. Policy Learned by the Q-Learning Algorithm with Optimized Epsilon Value

# %%
# Initialize the environment
env_with_subgoal = MazeEnv()

# Train the agent
q_table, total_rewards, steps_per_episode, convergence_episode, learning_time = q_learning(env_with_subgoal, episodes=250, alpha=0.1, gamma=0.95,
                                                                              epsilon=0.05, convergence_window=50, threshold=0.01)

# Show the agent navigating the maze
demonstrate_policy(env_with_subgoal, q_table)

# %% [markdown]
# ###4.3.6. Visualization of the Full Policy Learned by the Q-Learning Algorithm with Optimized Epsilon Value

# %%
# Visualize the learned policy
env_with_subgoal.visualize_policy(q_table)

# %% [markdown]
# ###4.3.7. Plots of Cumulative Reward and Steps per Episode with Optimized Epsilon Value

# %%
# Plot cumulative reward and steps over the number of episodes
plot_metrics(total_rewards, steps_per_episode)

# %% [markdown]
# ### 4.3.8. The Convergence Episode & The Time Required for Convergence with Optimized Epsilon Value

# %%
# Print the convergence episode
print(f"Episode of convergence: {convergence_episode}")
# Print the time required for convergence
print(f"Time required for convergence: {learning_time:.4f} seconds")
# Out:
# Episode of convergence: 122
# Time required for convergence: 0.0774 seconds

# %% [markdown]
# #5. Value Iteration Algorithm

# %%
def value_iteration(env, gamma=0.95, theta=1e-6):
    """
    Performs Value Iteration for the given environment with a timer to measure convergence time.

    This function applies the Value Iteration algorithm to solve the Markov Decision Process (MDP)
    in the given environment. The algorithm computes the optimal value function by iteratively
    updating the value estimates for each state based on the maximum expected reward. It stops
    once the change in the value function (delta) falls below a convergence threshold (theta).

    Args:
        env: The environment instance, which must provide `step`, `reset`, `observation_space`, and
             `action_space` properties and methods (e.g., compatible with OpenAI Gym environments).
        gamma (float): Discount factor (0 <= gamma <= 1) that determines the importance of future rewards.
        theta (float): Threshold for the convergence of value function updates. If the change in value
                       for all states is below this threshold, the algorithm stops.

    Returns:
        tuple: A tuple containing the following elements:
            - numpy.ndarray: The final value table representing the maximum expected reward for each state.
            - numpy.ndarray: The Q-table storing the action-value pairs for each state-action combination.
            - numpy.ndarray: The optimal policy derived from the value function.
            - list: A list tracking the maximum change (delta) in the value function at each iteration.
            - float: The time taken to converge.
    """
    # Start the timer
    start_time = time.time()

    # Initialize the value table with zeros
    value_table = np.zeros(env.observation_space.n)
    # Initialize the Q-table with zeros
    q_table = np.zeros((env.observation_space.n, env.action_space.n))
    # Track the maximum change in value function (delta) per iteration
    max_value_changes_per_iteration = []

    # Loop until the value function converges
    while True:
        # Keep track of value function change
        delta = 0

        # Iterate over all possible states
        for state in range(env.observation_space.n):

            # Loop over all actions for the current state
            for action in range(env.action_space.n):
                # Convert the state to (x, y) coordinates for the environment
                x, y = divmod(state % 100, 10)
                # Set the environment's agent position
                env.position = (x, y)
                # Set subgoal status based on state
                env.sub_goal_visited = (state >= 100)

                # Take the action and observe the new state, reward, and whether it's done
                new_state, reward, done, _ = env.step(action)
                # Compute Q-value for this action
                q_value = reward + gamma * value_table[new_state]
                # Store Q-value in the Q-table
                q_table[state, action] = q_value

            # Get the max Q-value for the current state
            new_value = max(q_table[state, :])
            # Update delta if change is larger
            delta = max(delta, abs(new_value - value_table[state]))
            # Set the updated value for the state
            value_table[state] = new_value

        # Store the maximum change (delta) for this iteration
        max_value_changes_per_iteration.append(delta)
        # If the value function has converged, exit the loop
        if delta < theta:
            break

    # End the timer and calculate the elapsed time
    end_time = time.time()
    iteration_time = end_time - start_time

    # Initialize the policy table with zeros
    policy = np.zeros(env.observation_space.n, dtype=int)
    # Derive the optimal policy from the Q-table
    for state in range(env.observation_space.n):
        # Get the action with the highest Q-value for each state
        policy[state] = np.argmax(q_table[state])

    return value_table, q_table, policy, max_value_changes_per_iteration, iteration_time

# %% [markdown]
# ## 5.1. Function for Plotting the Maximum Value Change per Iteration

# %%
def plot_convergence(max_value_changes_per_iteration):
    """Plots the convergence of the Value Iteration algorithm.

    This function visualizes how the maximum change in the value function (delta) evolves
    over iterations during the Value Iteration process. The plot shows the maximum value
    function change at each iteration, providing insight into how quickly the algorithm converges.

    Args:
        max_value_changes_per_iteration (list or array-like): A list or array containing the
            maximum change (delta) in the value function for each iteration of the algorithm.

    Returns:
        None: This function does not return a value but displays a plot.
    """
    # Create a figure
    plt.figure(figsize=(6, 4))

    # Plot delta (max value function change) over the number of iterations
    plt.plot(max_value_changes_per_iteration)

    # Set the ticks (labels) on the x-axis to show every 10th iteration
    plt.xticks(np.arange(0, len(max_value_changes_per_iteration), step=20))
    # Set the ticks (labels) on the y-axis, with steps of 1.5
    plt.yticks(np.arange(0, max(max_value_changes_per_iteration), step=1.5)) # update for the y-axis (change step for more or less values on the axes)

    # Label the axes
    plt.xlabel('Iterations')
    plt.ylabel('Maximum Value Function Change')
    # Set the title
    plt.title('Maximum Value Function Change per Iteration')

    # Enable the grid for better readability
    plt.grid(True)

    # Display the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 5.2. Application of the Value Iteration Algorithm to the Maze with Sub-goal

# %% [markdown]
# ###5.2.1. Policy Learned by the Value Iteration Algorithm

# %%
# Initialize the environment
env_with_subgoal = MazeEnv()

# Train the Agent
value_table, q_table, policy, max_value_changes_per_iteration, iteration_time = value_iteration(env_with_subgoal, gamma=0.95, theta=1e-4)

# Show the agent navigating the maze
demonstrate_policy(env_with_subgoal, q_table)

# %% [markdown]
# ###5.2.2. Visualization of the Full Policy Learned by the Value Iteration Algorithm

# %%
# Visualize the learned policy
env_with_subgoal.visualize_policy(q_table)

# %% [markdown]
# ###5.2.3. Plot of Maximum Value Change per Iteration

# %%
# Plot the maximum value changes over the number of iterations
plot_convergence(max_value_changes_per_iteration)

# %% [markdown]
# ### 5.2.4. The Convergence Iteration & The Time Required for Convergence

# %%
# Compute the convergence iteration
convergence_iteration = len(max_value_changes_per_iteration) - 1
# Print the convergence iteration
print(f"Iteration of convergence: {convergence_iteration}")
# Print the time required for convergence
print(f"Time required for convergence: {iteration_time:.4f} seconds")
# Out:
# Iteration of convergence: 225
# Time required for convergence: 1.0234 seconds

# %% [markdown]
# #6. Checks for Both Algorithms with Different Position of the Sub-goal in the Maze

# %%
# Ensure the previous subgoal is turned into a path
previous_sub_goal_pos = (5, 3)
maze[previous_sub_goal_pos] = PATH

# Change the position of the subgoal
sub_goal_pos = (3, 8)
maze[sub_goal_pos] = SUB_GOAL

# %% [markdown]
# ## 6.1. Q-Learning

# %% [markdown]
#  ### 6.1.1. Policy Learned by the Q-Learning Algorithm with Optimized Epsilon Value

# %%
# Initialize the environment
env_with_subgoal = MazeEnv()

# Train the agent
q_table, total_rewards, steps_per_episode, convergence_episode, learning_time = q_learning(env_with_subgoal, episodes=250, alpha=0.1, gamma=0.95,
                                                                              epsilon=0.05, convergence_window=50, threshold=0.01)

# Show the agent navigating the maze
demonstrate_policy(env_with_subgoal, q_table)

# %% [markdown]
# ### 6.1.2. Visualization of the Full Policy Learned by the Q-Learning Algorithm with Optimized Epsilon Value

# %%
# Visualize the learned policy
env_with_subgoal.visualize_policy(q_table)

# %% [markdown]
# ### 6.1.3. Plots of Cumulative Reward and Steps per Episode with Optimized Epsilon Value

# %%
# Plot cumulative reward and steps over the number of episodes
plot_metrics(total_rewards, steps_per_episode)

# %% [markdown]
# ### 6.1.4. The Convergence Episode & The Time Required for Convergence with Optimized Epsilon Value

# %%
# Print the convergence episode
print(f"Episode of convergence: {convergence_episode}")
# Print the time required for convergence
print(f"Time required for convergence: {learning_time:.4f} seconds")
# Out:
# Episode of convergence: 172
# Time required for convergence: 0.1421 seconds

# %% [markdown]
# # 6.2. Value Iteration

# %% [markdown]
# ### 6.2.1. Policy Learned by the Value Iteration Algorithm

# %%
# Initialize the environment
env_with_subgoal = MazeEnv()

# Train the agent
value_table, q_table, policy, max_value_changes_per_iteration, iteration_time = value_iteration(env_with_subgoal, gamma=0.95, theta=1e-4)

# Show the agent navigating the maze
demonstrate_policy(env_with_subgoal, q_table)

# %% [markdown]
# ###6.2.2. Visualization of the Full Policy Learned by the Value Iteration Algorithm

# %%
# Visualize the learned policy
env_with_subgoal.visualize_policy(q_table)

# %% [markdown]
# ###6.2.3. Plot of Maximum Value Change per Iteration

# %%
# Plot the maximum value changes over the number of iterations
plot_convergence(max_value_changes_per_iteration)

# %% [markdown]
# ### 6.2.4. The Convergence Iteration & The Time Required for Convergence

# %%
# Compute the convergence iteration
convergence_iteration = len(max_value_changes_per_iteration) - 1
# Print the convergence iteration
print(f"Iteration of convergence: {convergence_iteration}")
# Print the time required for convergence
print(f"Time required for convergence: {iteration_time:.4f} seconds")
# Out:
# Iteration of convergence: 225
# Time required for convergence: 0.5502 seconds
